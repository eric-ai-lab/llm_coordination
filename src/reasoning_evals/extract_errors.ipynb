# %%
import pandas as pd 
import re 
import numpy as np 
import json 
from fuzzywuzzy import process
# Out:
# /home/saaket/.conda/envs/llm_coordination/lib/python3.9/site-packages/fuzzywuzzy/fuzz.py:11: UserWarning: Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning
#   warnings.warn('Using slow pure-python SequenceMatcher. Install python-Levenshtein to remove this warning')

# %%
df = pd.read_csv('data/single_turn_trials_march_2.csv')

# %%
# Out:
# 0

# %%
ec_ans = df['EC Answer'].values
tom_ans = df['TOM Answer'].values
jp_ans = df['JP Answer'].values


ec_ans_ord = df['EC Answer Ordinal'].values
tom_ans_ord = df['TOM Answer Ordinal'].values
jp_ans_ord = df['JP Answer Ordinal'].values


ec_questions = df['EC Question'].values
tom_questions = df['TOM Question'].values
jp_questions = df['JP Question'].values

scenarios = df['State Description'].values

# %%
def find_answer_fuzzy(question_string, inference_string):
    selected_ordinal = '-2'
    def get_answer_ordinal(inference_string):
        match = re.search(r'([A-Z])[\.\)]', inference_string)
        if match:
            return match.group(1)
        else:
            return None

    def get_answer_text(inference_string):
        # print(inference_string)
        action_regex = r"Action:\s*(.*)"
        answer_regex = r"Answer:\s*(.*)"
        match = re.search(action_regex, inference_string)
        if match:
            return match.group(1)
        
        match = re.search(answer_regex, inference_string)
        if match:
            return match.group(1)
        
        return None
    
    # If there is only one instance of Action: action then we get the action string 
    answer_text = get_answer_text(inference_string)
    # extract ordinal from the answer 
    if answer_text == None:
        answer_text = inference_string

    selected_ordinal = get_answer_ordinal(answer_text)
    
    if selected_ordinal is None: 
        action_list = []
        # print("QUESTION STRING: ", question_string)
        if 'actions' in question_string.strip().lower():
            action_list = question_string.strip().lower().split('available actions:')[-1].split('\n')
        elif 'answer' in question_string.strip().lower():
            action_list = question_string.strip().lower().split('available answers:')[-1].split('\n') 
            # print(action_list)
        if '' in action_list:
            action_list = [a for a in action_list if a != '']
        if ' ' in action_list:
            action_list = [a for a in action_list if a != ' ']
        action_list = [re.sub(r'^[a-z]\.\s*', '', action).strip() for action in action_list]
        action_start = answer_text.find("Action:")
        if action_start == -1:
            action_start = answer_text.find("Answer:")

        if action_start == -1:
            answer_text = re.sub(r'^[a-z]\.\s*', '', answer_text).strip()
            best_match, score = process.extractOne(answer_text, action_list)
            selected_ordinal = chr(action_list.index(best_match) + 65)
        else:
            answer_text = answer_text[action_start + 7:].strip()
            answer_text = re.sub(r'^[a-z]\.\s*', '', answer_text).strip()
            best_match, score = process.extractOne(answer_text, action_list)
            selected_ordinal = chr(action_list.index(best_match) + 65)
    
    return selected_ordinal

# %%
all_models = ['mistral_Mistral-7B-Instruct-v02', 'mistral_Mixtral-8x7B-Instruct-v01', 'vicuna_vicuna-7b-v15', 'vicuna_vicuna-13b-v15', 'llama_Llama-2-13b-chat-hf', 'llama_Llama-2-70b-chat-hf', 'openai_gpt-4-0125']

# %%
logs = {all_models[i]: json.load(open(f'logs/all_{all_models[i]}0.json')) for i in range(len(all_models))}

# %%
def fuzzy_search_test(find_answer_fuzzy):
    text = '''Explanation: Bob has a Yellow 2 card which is immediately playable on the Yellow Stack. By revealing Bob's rank 2 cards, I will be providing a Play Clue for the Yellow 2, which aligns with our convention to prioritize Play Clues over Save Clues. This action directly contributes to our progress without risking a life or wasting a turn on a discard when a productive play is available.
    Action:N. Reveal Bob's rank 2 cards.'''

    question = '''It is currently My (Alice) turn. Current Stacks: Red - R1, Yellow - Y1, Green - G0, White - W0, Blue - B0 
    My cards based on my knowledge:  
    Card 0 could be: [Red, Yellow, Green, White, Blue] [3]
    Card 1 could be: [Red, Yellow, Green, White, Blue] [1, 2, 4, 5]
    Card 2 could be: [Red, Yellow, Green, White, Blue] [3]
    Card 3 could be: [Red, Yellow, Green, White, Blue] [1, 2, 4, 5]
    Card 4 could be: [Red, Yellow, Green, White, Blue] [1, 2, 4, 5]
    I can see Bob's Cards are:  
    [Card 0: Yellow 3]  
    [Card 1: White 5]  
    [Card 2: Yellow 2]  
    [Card 3: Yellow 4]  
    [Card 4: Blue 3]  
    Bob's Knowledge about his cards:  
    Bob believes his Card 0 could be:  [Red, Yellow, Green, White, Blue] [1, 2, 3, 4, 5]
    Bob believes his Card 1 could be:  [Red, Yellow, Green, White, Blue] [5]
    Bob believes his Card 2 could be:  [Red, Yellow, Green, White, Blue] [2, 3, 4]
    Bob believes his Card 3 could be:  [Red, Yellow, Green, White, Blue] [2, 3, 4]
    Bob believes his Card 4 could be:  [Red, Yellow, Green, White, Blue] [2, 3, 4]
    Remaining Reveal Tokens: 5 
    Remaining Lives: 3  
    Deck Size: 38 
    The discard pile is: []
    My Action History: [Reveal Bob's Rank 1 Cards, Reveal Bob's Rank 5 Cards]
    The next playable cards for each stack are:  
    Only Red 2 can be played on Red Stack  
    Only Yellow 2 can be played on Yellow Stack  
    Only Green 1 can be played on Green Stack  
    Only White 1 can be played on White Stack  
    Only Blue 1 can be played on Blue Stack


    What action should I take next? 
    Available Actions: 
    A. Play Card 0.
    B. Play Card 1.
    C. Play Card 2.
    D. Play Card 3.
    E. Play Card 4.
    F. Discard Card 0.
    G. Discard Card 1.
    H. Discard Card 2.
    I. Discard Card 3.
    J. Discard Card 4.
    K. Reveal Bob's Yellow color cards.
    L. Reveal Bob's White color cards.
    M. Reveal Bob's Blue color cards.
    N. Reveal Bob's rank 2 cards.
    O. Reveal Bob's rank 3 cards.
    P. Reveal Bob's rank 4 cards.
    Q. Reveal Bob's rank 5 cards.
    '''

    find_answer_fuzzy(question,text)

# %%
# scenario_len = len(ec_questions)
# model_cols = []
# for m in all_models: 
#     model_cols.extend([f'{m} Answer', f'{m} Answer Ordinal', f'{m} Answer Correct'])
# error_logs = pd.DataFrame(columns=['Scenario', 'Type', 'Question', 'GT Answer', 'GT Answer Ordinal'] + model_cols)


# for i in range(scenario_len):
#     print({'Scenario': scenarios[i], 'Question': ec_questions[i], 'GT Answer': ec_ans[i], 'GT Ordinal': ec_ans_ord[i], 'Type': 'EC'})
#     new_row = pd.DataFrame({'Scenario': scenarios[i], 'Question': ec_questions[i], 'GT Answer': ec_ans[i], 'GT Ordinal': ec_ans_ord[i], 'Type': 'EC'})
#     for m in all_models:
#         new_row[f'{m} Answer'] = logs[m]['EC_ANSWERS'][i]
#         llm_ec_answer_ordinal = find_answer_fuzzy(ec_questions[i], logs[model]['EC_ANSWERS'][i])
#         new_row[f'{m} Answer Ordinal'] = llm_ec_answer_ordinal
#         new_row[f'{m} Answer Correct'] = 1 if llm_ec_answer_ordinal in ec_ans_ord[i] else 0 
#         error_logs = pd.concat([error_logs, new_row], ignore_index=True)
    
#     new_row = pd.DataFrame({'Scenario': scenarios[i], 'Question': tom_questions[i], 'GT Answer': tom_ans[i], 'GT Ordinal': tom_ans_ord[i], 'Type': 'TOM'})
#     for m in all_models:
#         new_row[f'{m} Answer'] = logs[m]['TOM_ANSWERS'][i]
#         llm_tom_answer_ordinal = find_answer_fuzzy(tom_questions[i], logs[model]['TOM_ANSWERS'][i])
#         new_row[f'{m} Answer Ordinal'] = llm_tom_answer_ordinal
#         new_row[f'{m} Answer Correct'] = 1 if llm_tom_answer_ordinal in tom_ans_ord[i] else 0 
#         error_logs = pd.concat([error_logs, new_row], ignore_index=True)
    
#     new_row = pd.DataFrame({'Scenario': scenarios[i], 'Question': jp_questions[i], 'GT Answer': jp_ans[i], 'GT Ordinal': jp_ans_ord[i], 'Type': 'JP'})
#     for m in all_models:
#         new_row[f'{m} Answer'] = logs[m]['JP_ANSWERS'][i]
#         llm_jp_answer_ordinal = find_answer_fuzzy(jp_questions[i], logs[model]['JP_ANSWERS'][i])
#         new_row[f'{m} Answer Ordinal'] = llm_jp_answer_ordinal
#         new_row[f'{m} Answer Correct'] = 1 if llm_jp_answer_ordinal in jp_ans_ord[i] else 0 
#         error_logs = pd.concat([error_logs, new_row], ignore_index=True)
        
scenario_len = len(ec_questions)
model_cols = []
for m in all_models: 
    model_cols.extend([f'{m} Answer', f'{m} Answer Ordinal', f'{m} Answer Correct'])

data = []

for i in range(scenario_len):
    for type, questions, ans, ans_ord, answers_key in [('EC', ec_questions, ec_ans, ec_ans_ord, 'EC_ANSWERS'), 
                                                        ('TOM', tom_questions, tom_ans, tom_ans_ord, 'TOM_ANSWERS'), 
                                                        ('JP', jp_questions, jp_ans, jp_ans_ord, 'JP_ANSWERS')]:
        row = {'Scenario': scenarios[i], 'Question': questions[i], 'GT Answer': ans[i], 'GT Ordinal': ans_ord[i], 'Type': type}
        for m in all_models:
            row[f'{m} Answer'] = logs[m][answers_key][i]
            answer_ordinal = find_answer_fuzzy(questions[i], logs[m][answers_key][i])
            row[f'{m} Answer Ordinal'] = answer_ordinal
            row[f'{m} Answer Correct'] = 1 if answer_ordinal in ans_ord[i] else 0 
        data.append(row)

error_logs = pd.DataFrame(data, columns=['Scenario', 'Type', 'Question', 'GT Answer', 'GT Answer Ordinal'] + model_cols)
# Out:
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']

# %%
logs[m]['EC_ANSWERS'][0]
# Out:
# 'Explanation: Based on the information provided, all stacks are at 0, indicating that no cards have been played yet as the game starts with all stacks at 0 and cards are added in ascending order. Answer: B. No.'

# %%
ec_tags_string = '''
Counting/Arrangement, layout-related
counting/arrangement, layout-related
counting/arrangement, layout-related
counting/arrangement, dynamic_variables
counting/arrangement, layout-related
counting/arrangement, dynamic_variables
counting/arrangement, dynamic_variables
counting/arrangement, layout-related
counting/arrangement, layout-related
counting/arrangement, dynamic_variables
counting/arrangement, layout-related
counting/arrangement, layout-related
counting/arrangement, layout-related
counting/arrangement, layout-related
counting/arrangement, layout-related, dynamic_variables,
counting/arrangement, layout-related, dynamic_variables,
counting/arrangement, dynamic_variables
counting/arrangement, dynamic_variables
counting/arrangement, layout-related
counting/arrangement, layout-related
counting/arrangement, dynamic_variables
counting/arrangement, layout-related
counting/arrangement, layout-related
counting/arrangement, dynamic_variables
counting/arrangement, dynamic_variables
counting/arrangement, layout-related, dynamic_variables,
counting/arrangement, layout-related, dynamic_variables,
counting/arrangement, dynamic_variables
layout-related, dynamic_variables
layout-related, counting/arrangement
layout-related, counting/arrangement
layout-related, dynamic_variables
layout-related
layout-related
layout-related
counting/arrangement, dynamic_variables
counting/arrangement, layout-related, dynamic_variables,
counting/arrangement, dynamic_variables
layout-related
layout-related
counting/arrangement, layout-related, dynamic_variables,
layout-related, dynamic_variables
layout-related, dynamic_variables
layout-related, dynamic_variables
layout-related, dynamic_variables
counting/arrangement, dynamic_variables
layout-related, counting/arrangement
dynamic_variables
layout-related, dynamic_variables
layout-related, dynamic_variables
layout-related, dynamic_variables
layout-related, dynamic_variables
layout-related, counting/arrangement
layout-related, dynamic_variables
layout-related
layout-related
counting/arrangement, layout-related, dynamic_variables,
layout-related, dynamic_variables
layout-related
layout-related
layout-related
counting/arrangement, dynamic_variables
Counting/arrangement, dynamic_variables
Counting/arrangement, dynamic_variables
Counting/arrangement, dynamic_variables
Counting/arrangement, dynamic_variables
'''

ec_tags = ec_tags_string.split('\n')
ec_tags = [t.strip().lower().split(', ') for t in ec_tags if t != '']

# %%
un = set()
for tt in ec_tags:
    for rag in tt:
        un.add(rag)

# %%
un
# Out:
# {'counting/arrangement',
#  'dynamic_variables',
#  'dynamic_variables,',
#  'layout-related'}

# %%
# Find error percentage for each type of tag 

m = 'openai_gpt-4-0125'
scenario_len = len(ec_questions)

for m in all_models:
    counting_errors = 0
    layout_related_errors = 0
    dynamic_variable_errors = 0
    total_errors = 0
    counting_questions = 0
    layout_questions = 0
    for i in range(scenario_len):
        answer_ordinal = find_answer_fuzzy(ec_questions[i], logs[m]['EC_ANSWERS'][i])
        # print(ec_questions[i], logs[m]['EC_ANSWERS'][i])
        # print('EC: ', answer_ordinal, ec_ans_ord[i])
        is_ec_correct = 1 if answer_ordinal in ec_ans_ord[i] else 0
        if 'counting/arrangement' in ec_tags[i]:
            counting_questions += 1
            
        if 'layout-related' in ec_tags[i]:
            layout_questions += 1
        if is_ec_correct == 0:
            # for tag in ec_tags[i]:
            #     if tag == 'counting/arrangement':
            #         counting_errors += 1
            #     elif tag == 'layout-related':
            #         layout_related_errors += 1
            #     elif tag == 'dynamic_variables':
            #         dynamic_variable_errors += 1
            # total_errors += 1
            total_errors += 1 
            
            if 'counting/arrangement' in ec_tags[i]:
                counting_errors += 1
            
            if 'layout-related' in ec_tags[i]:
                layout_related_errors += 1
            print('TOTAL ERRORS: ', total_errors)
            print('COUNTING ERRORS: ', counting_errors)
            print('LAYOUT ERRORS: ', layout_related_errors)

    print(f'{m} Counting/Arrangement Error Percentage: {counting_errors / counting_questions}')
    print(f'{m} Layout Related Error Percentage: {layout_related_errors / layout_questions}')
    # print(f'{m} Dynamic Variable Error Percentage: {dynamic_variable_errors / total_errors}')
# Out:
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# TOTAL ERRORS:  1
# COUNTING ERRORS:  1
# LAYOUT ERRORS:  1
# TOTAL ERRORS:  2
# COUNTING ERRORS:  2
# LAYOUT ERRORS:  2
# TOTAL ERRORS:  3
# COUNTING ERRORS:  3
# LAYOUT ERRORS:  2
# TOTAL ERRORS:  4
# COUNTING ERRORS:  4
# LAYOUT ERRORS:  3
# TOTAL ERRORS:  5
# COUNTING ERRORS:  5
# LAYOUT ERRORS:  3
# TOTAL ERRORS:  6
# COUNTING ERRORS:  6
# LAYOUT ERRORS:  4
# TOTAL ERRORS:  7
# COUNTING ERRORS:  7
# LAYOUT ERRORS:  5
# TOTAL ERRORS:  8
# COUNTING ERRORS:  8
# LAYOUT ERRORS:  6
# TOTAL ERRORS:  9
# COUNTING ERRORS:  9
# LAYOUT ERRORS:  7
# TOTAL ERRORS:  10
# COUNTING ERRORS:  10
# LAYOUT ERRORS:  8
# TOTAL ERRORS:  11
# COUNTING ERRORS:  11
# LAYOUT ERRORS:  8
# TOTAL ERRORS:  12
# COUNTING ERRORS:  12
# LAYOUT ERRORS:  9
# TOTAL ERRORS:  13
# COUNTING ERRORS:  13
# LAYOUT ERRORS:  10
# TOTAL ERRORS:  14
# COUNTING ERRORS:  14
# LAYOUT ERRORS:  11
# TOTAL ERRORS:  15
# COUNTING ERRORS:  15
# LAYOUT ERRORS:  12
# TOTAL ERRORS:  16
# COUNTING ERRORS:  16
# LAYOUT ERRORS:  12
# TOTAL ERRORS:  17
# COUNTING ERRORS:  17
# LAYOUT ERRORS:  12
# TOTAL ERRORS:  18
# COUNTING ERRORS:  18
# LAYOUT ERRORS:  13
# TOTAL ERRORS:  19
# COUNTING ERRORS:  19
# LAYOUT ERRORS:  14
# TOTAL ERRORS:  20
# COUNTING ERRORS:  20
# LAYOUT ERRORS:  15
# TOTAL ERRORS:  21
# COUNTING ERRORS:  21
# LAYOUT ERRORS:  16
# TOTAL ERRORS:  22
# COUNTING ERRORS:  21
# LAYOUT ERRORS:  17
# TOTAL ERRORS:  23
# COUNTING ERRORS:  21
# LAYOUT ERRORS:  18
# TOTAL ERRORS:  24
# COUNTING ERRORS:  21
# LAYOUT ERRORS:  19
# TOTAL ERRORS:  25
# COUNTING ERRORS:  22
# LAYOUT ERRORS:  19
# TOTAL ERRORS:  26
# COUNTING ERRORS:  23
# LAYOUT ERRORS:  19
# TOTAL ERRORS:  27
# COUNTING ERRORS:  23
# LAYOUT ERRORS:  20
# TOTAL ERRORS:  28
# COUNTING ERRORS:  23
# LAYOUT ERRORS:  21
# TOTAL ERRORS:  29
# COUNTING ERRORS:  24
# LAYOUT ERRORS:  22
# TOTAL ERRORS:  30
# COUNTING ERRORS:  24
# LAYOUT ERRORS:  23
# TOTAL ERRORS:  31
# COUNTING ERRORS:  24
# LAYOUT ERRORS:  24
# TOTAL ERRORS:  32
# COUNTING ERRORS:  25
# LAYOUT ERRORS:  24
# TOTAL ERRORS:  33
# COUNTING ERRORS:  26
# LAYOUT ERRORS:  25
# TOTAL ERRORS:  34
# COUNTING ERRORS:  26
# LAYOUT ERRORS:  25
# TOTAL ERRORS:  35
# COUNTING ERRORS:  26
# LAYOUT ERRORS:  26
# TOTAL ERRORS:  36
# COUNTING ERRORS:  26
# LAYOUT ERRORS:  27
# TOTAL ERRORS:  37
# COUNTING ERRORS:  26
# LAYOUT ERRORS:  28
# TOTAL ERRORS:  38
# COUNTING ERRORS:  26
# LAYOUT ERRORS:  29
# TOTAL ERRORS:  39
# COUNTING ERRORS:  26
# LAYOUT ERRORS:  30
# TOTAL ERRORS:  40
# COUNTING ERRORS:  26
# LAYOUT ERRORS:  31
# TOTAL ERRORS:  41
# COUNTING ERRORS:  26
# LAYOUT ERRORS:  32
# TOTAL ERRORS:  42
# COUNTING ERRORS:  26
# LAYOUT ERRORS:  33
# TOTAL ERRORS:  43
# COUNTING ERRORS:  27
# LAYOUT ERRORS:  33
# TOTAL ERRORS:  44
# COUNTING ERRORS:  28
# LAYOUT ERRORS:  33
# TOTAL ERRORS:  45
# COUNTING ERRORS:  29
# LAYOUT ERRORS:  33
# mistral_Mistral-7B-Instruct-v02 Counting/Arrangement Error Percentage: 0.6744186046511628
# mistral_Mistral-7B-Instruct-v02 Layout Related Error Percentage: 0.7021276595744681
# TOTAL ERRORS:  1
# COUNTING ERRORS:  1
# LAYOUT ERRORS:  1
# TOTAL ERRORS:  2
# COUNTING ERRORS:  2
# LAYOUT ERRORS:  1
# TOTAL ERRORS:  3
# COUNTING ERRORS:  3
# LAYOUT ERRORS:  2
# TOTAL ERRORS:  4
# COUNTING ERRORS:  4
# LAYOUT ERRORS:  2
# TOTAL ERRORS:  5
# COUNTING ERRORS:  5
# LAYOUT ERRORS:  3
# TOTAL ERRORS:  6
# COUNTING ERRORS:  6
# LAYOUT ERRORS:  4
# TOTAL ERRORS:  7
# COUNTING ERRORS:  7
# LAYOUT ERRORS:  4
# TOTAL ERRORS:  8
# COUNTING ERRORS:  8
# LAYOUT ERRORS:  5
# TOTAL ERRORS:  9
# COUNTING ERRORS:  9
# LAYOUT ERRORS:  6
# TOTAL ERRORS:  10
# COUNTING ERRORS:  10
# LAYOUT ERRORS:  7
# TOTAL ERRORS:  11
# COUNTING ERRORS:  11
# LAYOUT ERRORS:  7
# TOTAL ERRORS:  12
# COUNTING ERRORS:  12
# LAYOUT ERRORS:  8
# TOTAL ERRORS:  13
# COUNTING ERRORS:  13
# LAYOUT ERRORS:  9
# TOTAL ERRORS:  14
# COUNTING ERRORS:  14
# LAYOUT ERRORS:  9
# TOTAL ERRORS:  15
# COUNTING ERRORS:  15
# LAYOUT ERRORS:  10
# TOTAL ERRORS:  16
# COUNTING ERRORS:  16
# LAYOUT ERRORS:  11
# TOTAL ERRORS:  17
# COUNTING ERRORS:  17
# LAYOUT ERRORS:  12
# TOTAL ERRORS:  18
# COUNTING ERRORS:  18
# LAYOUT ERRORS:  13
# TOTAL ERRORS:  19
# COUNTING ERRORS:  18
# LAYOUT ERRORS:  14
# TOTAL ERRORS:  20
# COUNTING ERRORS:  18
# LAYOUT ERRORS:  15
# TOTAL ERRORS:  21
# COUNTING ERRORS:  19
# LAYOUT ERRORS:  15
# TOTAL ERRORS:  22
# COUNTING ERRORS:  19
# LAYOUT ERRORS:  16
# TOTAL ERRORS:  23
# COUNTING ERRORS:  19
# LAYOUT ERRORS:  17
# TOTAL ERRORS:  24
# COUNTING ERRORS:  19
# LAYOUT ERRORS:  18
# TOTAL ERRORS:  25
# COUNTING ERRORS:  19
# LAYOUT ERRORS:  19
# TOTAL ERRORS:  26
# COUNTING ERRORS:  20
# LAYOUT ERRORS:  19
# TOTAL ERRORS:  27
# COUNTING ERRORS:  21
# LAYOUT ERRORS:  20
# TOTAL ERRORS:  28
# COUNTING ERRORS:  21
# LAYOUT ERRORS:  20
# TOTAL ERRORS:  29
# COUNTING ERRORS:  21
# LAYOUT ERRORS:  21
# TOTAL ERRORS:  30
# COUNTING ERRORS:  21
# LAYOUT ERRORS:  22
# TOTAL ERRORS:  31
# COUNTING ERRORS:  22
# LAYOUT ERRORS:  23
# TOTAL ERRORS:  32
# COUNTING ERRORS:  22
# LAYOUT ERRORS:  24
# TOTAL ERRORS:  33
# COUNTING ERRORS:  22
# LAYOUT ERRORS:  25
# TOTAL ERRORS:  34
# COUNTING ERRORS:  22
# LAYOUT ERRORS:  26
# TOTAL ERRORS:  35
# COUNTING ERRORS:  23
# LAYOUT ERRORS:  27
# TOTAL ERRORS:  36
# COUNTING ERRORS:  23
# LAYOUT ERRORS:  28
# TOTAL ERRORS:  37
# COUNTING ERRORS:  24
# LAYOUT ERRORS:  28
# TOTAL ERRORS:  38
# COUNTING ERRORS:  25
# LAYOUT ERRORS:  28
# TOTAL ERRORS:  39
# COUNTING ERRORS:  26
# LAYOUT ERRORS:  28
# mistral_Mixtral-8x7B-Instruct-v01 Counting/Arrangement Error Percentage: 0.6046511627906976
# mistral_Mixtral-8x7B-Instruct-v01 Layout Related Error Percentage: 0.5957446808510638
# TOTAL ERRORS:  1
# COUNTING ERRORS:  1
# LAYOUT ERRORS:  1
# TOTAL ERRORS:  2
# COUNTING ERRORS:  2
# LAYOUT ERRORS:  2
# TOTAL ERRORS:  3
# COUNTING ERRORS:  3
# LAYOUT ERRORS:  3
# TOTAL ERRORS:  4
# COUNTING ERRORS:  4
# LAYOUT ERRORS:  3
# TOTAL ERRORS:  5
# COUNTING ERRORS:  5
# LAYOUT ERRORS:  3
# TOTAL ERRORS:  6
# COUNTING ERRORS:  6
# LAYOUT ERRORS:  3
# TOTAL ERRORS:  7
# COUNTING ERRORS:  7
# LAYOUT ERRORS:  4
# TOTAL ERRORS:  8
# COUNTING ERRORS:  8
# LAYOUT ERRORS:  4
# TOTAL ERRORS:  9
# COUNTING ERRORS:  9
# LAYOUT ERRORS:  5
# TOTAL ERRORS:  10
# COUNTING ERRORS:  10
# LAYOUT ERRORS:  6
# TOTAL ERRORS:  11
# COUNTING ERRORS:  11
# LAYOUT ERRORS:  7
# TOTAL ERRORS:  12
# COUNTING ERRORS:  12
# LAYOUT ERRORS:  8
# TOTAL ERRORS:  13
# COUNTING ERRORS:  13
# LAYOUT ERRORS:  8
# TOTAL ERRORS:  14
# COUNTING ERRORS:  14
# LAYOUT ERRORS:  9
# TOTAL ERRORS:  15
# COUNTING ERRORS:  15
# LAYOUT ERRORS:  9
# TOTAL ERRORS:  16
# COUNTING ERRORS:  16
# LAYOUT ERRORS:  9
# TOTAL ERRORS:  17
# COUNTING ERRORS:  17
# LAYOUT ERRORS:  9
# TOTAL ERRORS:  18
# COUNTING ERRORS:  18
# LAYOUT ERRORS:  10
# TOTAL ERRORS:  19
# COUNTING ERRORS:  18
# LAYOUT ERRORS:  11
# TOTAL ERRORS:  20
# COUNTING ERRORS:  19
# LAYOUT ERRORS:  12
# TOTAL ERRORS:  21
# COUNTING ERRORS:  20
# LAYOUT ERRORS:  13
# TOTAL ERRORS:  22
# COUNTING ERRORS:  20
# LAYOUT ERRORS:  14
# TOTAL ERRORS:  23
# COUNTING ERRORS:  20
# LAYOUT ERRORS:  15
# TOTAL ERRORS:  24
# COUNTING ERRORS:  20
# LAYOUT ERRORS:  16
# TOTAL ERRORS:  25
# COUNTING ERRORS:  21
# LAYOUT ERRORS:  16
# TOTAL ERRORS:  26
# COUNTING ERRORS:  22
# LAYOUT ERRORS:  17
# TOTAL ERRORS:  27
# COUNTING ERRORS:  23
# LAYOUT ERRORS:  17
# TOTAL ERRORS:  28
# COUNTING ERRORS:  23
# LAYOUT ERRORS:  18
# TOTAL ERRORS:  29
# COUNTING ERRORS:  24
# LAYOUT ERRORS:  19
# TOTAL ERRORS:  30
# COUNTING ERRORS:  24
# LAYOUT ERRORS:  20
# TOTAL ERRORS:  31
# COUNTING ERRORS:  24
# LAYOUT ERRORS:  21
# TOTAL ERRORS:  32
# COUNTING ERRORS:  25
# LAYOUT ERRORS:  21
# TOTAL ERRORS:  33
# COUNTING ERRORS:  26
# LAYOUT ERRORS:  22
# TOTAL ERRORS:  34
# COUNTING ERRORS:  26
# LAYOUT ERRORS:  22
# TOTAL ERRORS:  35
# COUNTING ERRORS:  26
# LAYOUT ERRORS:  23
# TOTAL ERRORS:  36
# COUNTING ERRORS:  26
# LAYOUT ERRORS:  24
# TOTAL ERRORS:  37
# COUNTING ERRORS:  26
# LAYOUT ERRORS:  25
# TOTAL ERRORS:  38
# COUNTING ERRORS:  26
# LAYOUT ERRORS:  26
# TOTAL ERRORS:  39
# COUNTING ERRORS:  26
# LAYOUT ERRORS:  27
# TOTAL ERRORS:  40
# COUNTING ERRORS:  26
# LAYOUT ERRORS:  28
# TOTAL ERRORS:  41
# COUNTING ERRORS:  27
# LAYOUT ERRORS:  29
# TOTAL ERRORS:  42
# COUNTING ERRORS:  28
# LAYOUT ERRORS:  29
# TOTAL ERRORS:  43
# COUNTING ERRORS:  29
# LAYOUT ERRORS:  29
# TOTAL ERRORS:  44
# COUNTING ERRORS:  30
# LAYOUT ERRORS:  29
# TOTAL ERRORS:  45
# COUNTING ERRORS:  31
# LAYOUT ERRORS:  29
# vicuna_vicuna-7b-v15 Counting/Arrangement Error Percentage: 0.7209302325581395
# vicuna_vicuna-7b-v15 Layout Related Error Percentage: 0.6170212765957447
# TOTAL ERRORS:  1
# COUNTING ERRORS:  1
# LAYOUT ERRORS:  1
# TOTAL ERRORS:  2
# COUNTING ERRORS:  2
# LAYOUT ERRORS:  2
# TOTAL ERRORS:  3
# COUNTING ERRORS:  3
# LAYOUT ERRORS:  3
# TOTAL ERRORS:  4
# COUNTING ERRORS:  4
# LAYOUT ERRORS:  3
# TOTAL ERRORS:  5
# COUNTING ERRORS:  5
# LAYOUT ERRORS:  4
# TOTAL ERRORS:  6
# COUNTING ERRORS:  6
# LAYOUT ERRORS:  4
# TOTAL ERRORS:  7
# COUNTING ERRORS:  7
# LAYOUT ERRORS:  4
# TOTAL ERRORS:  8
# COUNTING ERRORS:  8
# LAYOUT ERRORS:  5
# TOTAL ERRORS:  9
# COUNTING ERRORS:  9
# LAYOUT ERRORS:  5
# TOTAL ERRORS:  10
# COUNTING ERRORS:  10
# LAYOUT ERRORS:  6
# TOTAL ERRORS:  11
# COUNTING ERRORS:  11
# LAYOUT ERRORS:  7
# TOTAL ERRORS:  12
# COUNTING ERRORS:  12
# LAYOUT ERRORS:  8
# TOTAL ERRORS:  13
# COUNTING ERRORS:  13
# LAYOUT ERRORS:  8
# TOTAL ERRORS:  14
# COUNTING ERRORS:  14
# LAYOUT ERRORS:  8
# TOTAL ERRORS:  15
# COUNTING ERRORS:  15
# LAYOUT ERRORS:  8
# TOTAL ERRORS:  16
# COUNTING ERRORS:  15
# LAYOUT ERRORS:  9
# TOTAL ERRORS:  17
# COUNTING ERRORS:  16
# LAYOUT ERRORS:  10
# TOTAL ERRORS:  18
# COUNTING ERRORS:  17
# LAYOUT ERRORS:  11
# TOTAL ERRORS:  19
# COUNTING ERRORS:  17
# LAYOUT ERRORS:  12
# TOTAL ERRORS:  20
# COUNTING ERRORS:  17
# LAYOUT ERRORS:  13
# TOTAL ERRORS:  21
# COUNTING ERRORS:  17
# LAYOUT ERRORS:  14
# TOTAL ERRORS:  22
# COUNTING ERRORS:  17
# LAYOUT ERRORS:  15
# TOTAL ERRORS:  23
# COUNTING ERRORS:  18
# LAYOUT ERRORS:  15
# TOTAL ERRORS:  24
# COUNTING ERRORS:  19
# LAYOUT ERRORS:  16
# TOTAL ERRORS:  25
# COUNTING ERRORS:  19
# LAYOUT ERRORS:  17
# TOTAL ERRORS:  26
# COUNTING ERRORS:  19
# LAYOUT ERRORS:  18
# TOTAL ERRORS:  27
# COUNTING ERRORS:  20
# LAYOUT ERRORS:  19
# TOTAL ERRORS:  28
# COUNTING ERRORS:  20
# LAYOUT ERRORS:  20
# TOTAL ERRORS:  29
# COUNTING ERRORS:  21
# LAYOUT ERRORS:  20
# TOTAL ERRORS:  30
# COUNTING ERRORS:  22
# LAYOUT ERRORS:  21
# TOTAL ERRORS:  31
# COUNTING ERRORS:  22
# LAYOUT ERRORS:  21
# TOTAL ERRORS:  32
# COUNTING ERRORS:  22
# LAYOUT ERRORS:  22
# TOTAL ERRORS:  33
# COUNTING ERRORS:  22
# LAYOUT ERRORS:  23
# TOTAL ERRORS:  34
# COUNTING ERRORS:  22
# LAYOUT ERRORS:  24
# TOTAL ERRORS:  35
# COUNTING ERRORS:  22
# LAYOUT ERRORS:  25
# TOTAL ERRORS:  36
# COUNTING ERRORS:  22
# LAYOUT ERRORS:  26
# TOTAL ERRORS:  37
# COUNTING ERRORS:  22
# LAYOUT ERRORS:  27
# TOTAL ERRORS:  38
# COUNTING ERRORS:  23
# LAYOUT ERRORS:  27
# TOTAL ERRORS:  39
# COUNTING ERRORS:  24
# LAYOUT ERRORS:  27
# vicuna_vicuna-13b-v15 Counting/Arrangement Error Percentage: 0.5581395348837209
# vicuna_vicuna-13b-v15 Layout Related Error Percentage: 0.574468085106383
# TOTAL ERRORS:  1
# COUNTING ERRORS:  1
# LAYOUT ERRORS:  1
# TOTAL ERRORS:  2
# COUNTING ERRORS:  2
# LAYOUT ERRORS:  2
# TOTAL ERRORS:  3
# COUNTING ERRORS:  3
# LAYOUT ERRORS:  2
# TOTAL ERRORS:  4
# COUNTING ERRORS:  4
# LAYOUT ERRORS:  3
# TOTAL ERRORS:  5
# COUNTING ERRORS:  5
# LAYOUT ERRORS:  3
# TOTAL ERRORS:  6
# COUNTING ERRORS:  6
# LAYOUT ERRORS:  4
# TOTAL ERRORS:  7
# COUNTING ERRORS:  7
# LAYOUT ERRORS:  5
# TOTAL ERRORS:  8
# COUNTING ERRORS:  8
# LAYOUT ERRORS:  6
# TOTAL ERRORS:  9
# COUNTING ERRORS:  9
# LAYOUT ERRORS:  7
# TOTAL ERRORS:  10
# COUNTING ERRORS:  10
# LAYOUT ERRORS:  8
# TOTAL ERRORS:  11
# COUNTING ERRORS:  11
# LAYOUT ERRORS:  9
# TOTAL ERRORS:  12
# COUNTING ERRORS:  12
# LAYOUT ERRORS:  10
# TOTAL ERRORS:  13
# COUNTING ERRORS:  13
# LAYOUT ERRORS:  11
# TOTAL ERRORS:  14
# COUNTING ERRORS:  14
# LAYOUT ERRORS:  11
# TOTAL ERRORS:  15
# COUNTING ERRORS:  15
# LAYOUT ERRORS:  11
# TOTAL ERRORS:  16
# COUNTING ERRORS:  16
# LAYOUT ERRORS:  12
# TOTAL ERRORS:  17
# COUNTING ERRORS:  16
# LAYOUT ERRORS:  13
# TOTAL ERRORS:  18
# COUNTING ERRORS:  17
# LAYOUT ERRORS:  14
# TOTAL ERRORS:  19
# COUNTING ERRORS:  17
# LAYOUT ERRORS:  15
# TOTAL ERRORS:  20
# COUNTING ERRORS:  17
# LAYOUT ERRORS:  16
# TOTAL ERRORS:  21
# COUNTING ERRORS:  18
# LAYOUT ERRORS:  16
# TOTAL ERRORS:  22
# COUNTING ERRORS:  19
# LAYOUT ERRORS:  17
# TOTAL ERRORS:  23
# COUNTING ERRORS:  20
# LAYOUT ERRORS:  17
# TOTAL ERRORS:  24
# COUNTING ERRORS:  20
# LAYOUT ERRORS:  18
# TOTAL ERRORS:  25
# COUNTING ERRORS:  21
# LAYOUT ERRORS:  18
# TOTAL ERRORS:  26
# COUNTING ERRORS:  21
# LAYOUT ERRORS:  18
# TOTAL ERRORS:  27
# COUNTING ERRORS:  21
# LAYOUT ERRORS:  19
# TOTAL ERRORS:  28
# COUNTING ERRORS:  21
# LAYOUT ERRORS:  20
# TOTAL ERRORS:  29
# COUNTING ERRORS:  21
# LAYOUT ERRORS:  21
# TOTAL ERRORS:  30
# COUNTING ERRORS:  21
# LAYOUT ERRORS:  22
# TOTAL ERRORS:  31
# COUNTING ERRORS:  21
# LAYOUT ERRORS:  23
# TOTAL ERRORS:  32
# COUNTING ERRORS:  21
# LAYOUT ERRORS:  24
# TOTAL ERRORS:  33
# COUNTING ERRORS:  21
# LAYOUT ERRORS:  25
# TOTAL ERRORS:  34
# COUNTING ERRORS:  22
# LAYOUT ERRORS:  25
# TOTAL ERRORS:  35
# COUNTING ERRORS:  23
# LAYOUT ERRORS:  25
# TOTAL ERRORS:  36
# COUNTING ERRORS:  24
# LAYOUT ERRORS:  25
# llama_Llama-2-13b-chat-hf Counting/Arrangement Error Percentage: 0.5581395348837209
# llama_Llama-2-13b-chat-hf Layout Related Error Percentage: 0.5319148936170213
# TOTAL ERRORS:  1
# COUNTING ERRORS:  1
# LAYOUT ERRORS:  1
# TOTAL ERRORS:  2
# COUNTING ERRORS:  2
# LAYOUT ERRORS:  2
# TOTAL ERRORS:  3
# COUNTING ERRORS:  3
# LAYOUT ERRORS:  2
# TOTAL ERRORS:  4
# COUNTING ERRORS:  4
# LAYOUT ERRORS:  3
# TOTAL ERRORS:  5
# COUNTING ERRORS:  5
# LAYOUT ERRORS:  4
# TOTAL ERRORS:  6
# COUNTING ERRORS:  6
# LAYOUT ERRORS:  5
# TOTAL ERRORS:  7
# COUNTING ERRORS:  7
# LAYOUT ERRORS:  6
# TOTAL ERRORS:  8
# COUNTING ERRORS:  8
# LAYOUT ERRORS:  7
# TOTAL ERRORS:  9
# COUNTING ERRORS:  9
# LAYOUT ERRORS:  8
# TOTAL ERRORS:  10
# COUNTING ERRORS:  10
# LAYOUT ERRORS:  9
# TOTAL ERRORS:  11
# COUNTING ERRORS:  11
# LAYOUT ERRORS:  9
# TOTAL ERRORS:  12
# COUNTING ERRORS:  12
# LAYOUT ERRORS:  9
# TOTAL ERRORS:  13
# COUNTING ERRORS:  13
# LAYOUT ERRORS:  10
# TOTAL ERRORS:  14
# COUNTING ERRORS:  14
# LAYOUT ERRORS:  10
# TOTAL ERRORS:  15
# COUNTING ERRORS:  15
# LAYOUT ERRORS:  10
# TOTAL ERRORS:  16
# COUNTING ERRORS:  16
# LAYOUT ERRORS:  10
# TOTAL ERRORS:  17
# COUNTING ERRORS:  17
# LAYOUT ERRORS:  11
# TOTAL ERRORS:  18
# COUNTING ERRORS:  17
# LAYOUT ERRORS:  12
# TOTAL ERRORS:  19
# COUNTING ERRORS:  17
# LAYOUT ERRORS:  13
# TOTAL ERRORS:  20
# COUNTING ERRORS:  17
# LAYOUT ERRORS:  14
# TOTAL ERRORS:  21
# COUNTING ERRORS:  18
# LAYOUT ERRORS:  15
# TOTAL ERRORS:  22
# COUNTING ERRORS:  19
# LAYOUT ERRORS:  15
# TOTAL ERRORS:  23
# COUNTING ERRORS:  19
# LAYOUT ERRORS:  16
# TOTAL ERRORS:  24
# COUNTING ERRORS:  19
# LAYOUT ERRORS:  17
# TOTAL ERRORS:  25
# COUNTING ERRORS:  19
# LAYOUT ERRORS:  18
# TOTAL ERRORS:  26
# COUNTING ERRORS:  20
# LAYOUT ERRORS:  18
# TOTAL ERRORS:  27
# COUNTING ERRORS:  21
# LAYOUT ERRORS:  19
# TOTAL ERRORS:  28
# COUNTING ERRORS:  21
# LAYOUT ERRORS:  20
# TOTAL ERRORS:  29
# COUNTING ERRORS:  21
# LAYOUT ERRORS:  21
# TOTAL ERRORS:  30
# COUNTING ERRORS:  22
# LAYOUT ERRORS:  22
# TOTAL ERRORS:  31
# COUNTING ERRORS:  22
# LAYOUT ERRORS:  23
# TOTAL ERRORS:  32
# COUNTING ERRORS:  22
# LAYOUT ERRORS:  24
# TOTAL ERRORS:  33
# COUNTING ERRORS:  23
# LAYOUT ERRORS:  24
# llama_Llama-2-70b-chat-hf Counting/Arrangement Error Percentage: 0.5348837209302325
# llama_Llama-2-70b-chat-hf Layout Related Error Percentage: 0.5106382978723404
# TOTAL ERRORS:  1
# COUNTING ERRORS:  1
# LAYOUT ERRORS:  1
# TOTAL ERRORS:  2
# COUNTING ERRORS:  2
# LAYOUT ERRORS:  2
# TOTAL ERRORS:  3
# COUNTING ERRORS:  3
# LAYOUT ERRORS:  3
# TOTAL ERRORS:  4
# COUNTING ERRORS:  4
# LAYOUT ERRORS:  4
# TOTAL ERRORS:  5
# COUNTING ERRORS:  4
# LAYOUT ERRORS:  5
# TOTAL ERRORS:  6
# COUNTING ERRORS:  5
# LAYOUT ERRORS:  6
# TOTAL ERRORS:  7
# COUNTING ERRORS:  6
# LAYOUT ERRORS:  7
# TOTAL ERRORS:  8
# COUNTING ERRORS:  6
# LAYOUT ERRORS:  8
# TOTAL ERRORS:  9
# COUNTING ERRORS:  6
# LAYOUT ERRORS:  9
# TOTAL ERRORS:  10
# COUNTING ERRORS:  6
# LAYOUT ERRORS:  10
# openai_gpt-4-0125 Counting/Arrangement Error Percentage: 0.13953488372093023
# openai_gpt-4-0125 Layout Related Error Percentage: 0.2127659574468085

# %%
# Find percent cases where both EC and ToM were correct for a model, but JP was still wrong

m = 'openai_gpt-4-0125'
jp_wrong_total = 0
synthesis_failure_total = 0
component_failure_toral = 0
for i in range(scenario_len):
    # for type, questions, ans, ans_ord, answers_key in [('EC', ec_questions, ec_ans, ec_ans_ord, 'EC_ANSWERS'), 
    #                                                     ('TOM', tom_questions, tom_ans, tom_ans_ord, 'TOM_ANSWERS'), 
    #                                                     ('JP', jp_questions, jp_ans, jp_ans_ord, 'JP_ANSWERS')]:
    #     row = {'Scenario': scenarios[i], 'Question': questions[i], 'GT Answer': ans[i], 'GT Ordinal': ans_ord[i], 'Type': type}
    #     for m in all_models:
    #         row[f'{m} Answer'] = logs[m][answers_key][i]
    #         answer_ordinal = find_answer_fuzzy(questions[i], logs[m][answers_key][i])
    #         row[f'{m} Answer Ordinal'] = answer_ordinal
    #         row[f'{m} Answer Correct'] = 1 if answer_ordinal in ans_ord[i] else 0 
    #     data.append(row)

    answer_ordinal = find_answer_fuzzy(ec_questions[i], logs[m]['EC_ANSWERS'][i])
    # print(ec_questions[i], logs[m]['EC_ANSWERS'][i])
    print('EC: ', answer_ordinal, ec_ans_ord[i])
    is_ec_correct = 1 if answer_ordinal in ec_ans_ord[i] else 0
    

    answer_ordinal = find_answer_fuzzy(tom_questions[i], logs[m]['TOM_ANSWERS'][i])
    # print(tom_questions[i], logs[m]['TOM_ANSWERS'][i])
    print('TOM: ', answer_ordinal, tom_ans_ord[i])
    is_tom_correct = 1 if answer_ordinal in tom_ans_ord[i] else 0

    answer_ordinal = find_answer_fuzzy(jp_questions[i], logs[m]['JP_ANSWERS'][i])
    # print(jp_questions[i], logs[m]['JP_ANSWERS'][i])
    print('JP: ', answer_ordinal, jp_ans_ord[i])
    is_jp_correct = 1 if answer_ordinal in jp_ans_ord[i] else 0

    if not is_jp_correct:
        jp_wrong_total += 1

        if is_ec_correct and is_tom_correct:
            synthesis_failure_total+=1 
        
        if not is_ec_correct or not is_tom_correct:
            component_failure_toral+=1


print(jp_wrong_total / scenario_len)
print('SYNTHESIS FAILURE: ', synthesis_failure_total / jp_wrong_total)
print('COMPONENT FAILURE: ', component_failure_toral / jp_wrong_total)
# Out:
# EC:  B B
# TOM:  B E
# JP:  L O
# EC:  E E
# TOM:  E E
# JP:  L O
# EC:  B B
# TOM:  A D
# JP:  N N
# EC:  B B
# TOM:  E A
# JP:  K K
# EC:  C A
# TOM:  E E
# JP:  E E
# EC:  D D
# TOM:  J F,G
# JP:  G G,H
# EC:  C C
# TOM:  G G
# JP:  G G
# EC:  A A
# TOM:  A F
# JP:  K P,N
# EC:  C B
# TOM:  G G
# JP:  Q Q
# EC:  B B
# TOM:  C G
# JP:  M Q
# EC:  A A
# TOM:  B H
# JP:  O R
# EC:  B B
# TOM:  D F
# JP:  N Q
# EC:  A A
# TOM:  F H
# JP:  P R
# EC:  D D
# TOM:  E E
# JP:  O O
# EC:  B B
# TOM:  C H
# JP:  M R
# EC:  A A
# TOM:  B F
# JP:  N P
# EC:  B B
# TOM:  A A
# JP:  K K
# EC:  A A
# TOM:  J B
# JP:  M A
# EC:  B A
# TOM:  A A
# JP:  K K
# EC:  B B
# TOM:  A A
# JP:  K K
# EC:  B B
# TOM:  B G
# JP:  K Q
# EC:  B A
# TOM:  E F
# JP:  K P
# EC:  A A
# TOM:  B D
# JP:  M N
# EC:  B B
# TOM:  G G
# JP:  A G
# EC:  B B
# TOM:  F F,G
# JP:  G F
# EC:  A A
# TOM:  E E
# JP:  E E
# EC:  B B
# TOM:  B D
# JP:  L N
# EC:  A A
# TOM:  A B
# JP:  K L
# EC:  B B
# TOM:  B B
# JP:  D C
# EC:  B B
# TOM:  A A
# JP:  A C
# EC:  B B
# TOM:  B B
# JP:  A C
# EC:  B B
# TOM:  D A
# JP:  B B
# EC:  C C
# TOM:  J J,D,E
# JP:  A C,D
# EC:  B B
# TOM:  E E
# JP:  A D
# EC:  B B
# TOM:  E E,G,I
# JP:  C C
# EC:  E E
# TOM:  B B
# JP:  D A,B,C
# EC:  D D
# TOM:  C G,J
# JP:  D D
# EC:  D D
# TOM:  A A,C
# JP:  C C
# EC:  A A
# TOM:  A A,B
# JP:  D D
# EC:  A B
# TOM:  B D,B
# JP:  E D,F
# EC:  A B
# TOM:  D A
# JP:  D C
# EC:  B B
# TOM:  B A,C
# JP:  D E
# EC:  D D
# TOM:  B A,C
# JP:  A E
# EC:  B B
# TOM:  B A,C
# JP:  A E
# EC:  C C
# TOM:  B A,C
# JP:  A D,E
# EC:  D D
# TOM:  A A
# JP:  C B
# EC:  A B
# TOM:  B E,L
# JP:  A D
# EC:  B B
# TOM:  E E
# JP:  B C,E
# EC:  B B
# TOM:  B B
# JP:  B B
# EC:  B B
# TOM:  B C
# JP:  B C
# EC:  C C
# TOM:  B B
# JP:  A B
# EC:  B B
# TOM:  B C
# JP:  C C
# EC:  A A
# TOM:  B B
# JP:  C C
# EC:  A B
# TOM:  B B
# JP:  A B
# EC:  A B
# TOM:  B B
# JP:  A A
# EC:  A A
# TOM:  A A
# JP:  A C
# EC:  D D
# TOM:  D D
# JP:  D A
# EC:  A A
# TOM:  B B
# JP:  C D
# EC:  A B
# TOM:  B A,E
# JP:  A B
# EC:  A A
# TOM:  C C
# JP:  A B
# EC:  B B
# TOM:  B B
# JP:  C C
# EC:  D D
# TOM:  A B
# JP:  B B
# EC:  A A
# TOM:  A A
# JP:  A C
# EC:  B B
# TOM:  C A
# JP:  B B
# EC:  B B
# TOM:  A C
# JP:  D A,B
# EC:  C C
# TOM:  A A
# JP:  C C
# 0.6363636363636364
# SYNTHESIS FAILURE:  0.40476190476190477
# COMPONENT FAILURE:  0.5952380952380952

# %%
error_logs
# Out:
#                                               Scenario Type
# 0    It is currently My (Alice) turn. Current Stack...   EC  \
# 1    It is currently My (Alice) turn. Current Stack...  TOM
# 2    It is currently My (Alice) turn. Current Stack...   JP
# 3    It is currently My (Alice) turn. Current Stack...   EC
# 4    It is currently My (Alice) turn. Current Stack...  TOM
# ..                                                 ...  ...
# 193  I am holding nothing. Bob is holding plate. Co...  TOM
# 194  I am holding nothing. Bob is holding plate. Co...   JP
# 195  I am holding nothing. Bob is holding tomato. C...   EC
# 196  I am holding nothing. Bob is holding tomato. C...  TOM
# 197  I am holding nothing. Bob is holding tomato. C...   JP
#
#                                               Question
# 0    It is currently My (Alice) turn. Current Stack...  \
# 1    It is currently My (Alice) turn. Current Stack...
# 2    It is currently My (Alice) turn. Current Stack...
# 3    It is currently My (Alice) turn. Current Stack...
# 4    It is currently My (Alice) turn. Current Stack...
# ..                                                 ...
# 193  I am holding nothing. Bob is holding plate. Co...
# 194  You are holding nothing. Bob is holding plate....
# 195  I am holding nothing. Bob is holding tomato. C...
# 196  I am holding nothing. Bob is holding tomato. C...
# 197  You are holding nothing. Bob is holding tomato...
#
#                       GT Answer  GT Answer Ordinal
# 0                           No.                NaN  \
# 1    Reveal Bob's rank 1 cards.                NaN
# 2    Reveal Bob's rank 1 cards.                NaN
# 3                      1 stack.                NaN
# 4    Reveal Bob's rank 2 cards.                NaN
# ..                          ...                ...
# 193                        wait                NaN
# 194     Pick up onion or tomato                NaN
# 195                   1 tomato.                NaN
# 196     Place tomato in cooker.                NaN
# 197              Pick up plate.                NaN
#
#                 mistral_Mistral-7B-Instruct-v02 Answer
# 0     Based on the information provided, there have...  \
# 1     Explanation: Based on the current state of th...
# 2     Explanation: Based on the current state of th...
# 3     Explanation: Based on the current state of th...
# 4     Explanation: Bob needs information to play hi...
# ..                                                 ...
# 193   Explanation: Bob is holding an empty plate an...
# 194   Explanation: Since Bob is holding a plate, I ...
# 195   Explanation: In order to cook soup in Overcoo...
# 196   Explanation: Since Bob is holding a tomato an...
# 197   Explanation: Since Bob is holding a tomato, I...
#
#     mistral_Mistral-7B-Instruct-v02 Answer Ordinal
# 0                                                B  \
# 1                                                E
# 2                                                K
# 3                                                C
# 4                                                E
# ..                                             ...
# 193                                              A
# 194                                              D
# 195                                              A
# 196                                              B
# 197                                              A
#
#      mistral_Mistral-7B-Instruct-v02 Answer Correct
# 0                                                 1  \
# 1                                                 1
# 2                                                 0
# 3                                                 0
# 4                                                 1
# ..                                              ...
# 193                                               0
# 194                                               0
# 195                                               0
# 196                                               0
# 197                                               0
#
#               mistral_Mixtral-8x7B-Instruct-v01 Answer
# 0     Explanation: Based on the information provide...  \
# 1     Explanation: Based on the current state of th...
# 2     Explanation: Based on the information provide...
# 3     Explanation: Based on the current stacks, onl...
# 4     Explanation: Bob has a Yellow 1 in his hand w...
# ..                                                 ...
# 193   Explanation: Since Bob is currently holding a...
# 194   Explanation: Since Bob is holding a plate and...
# 195   Explanation: The cooker needs one onion to st...
# 196   Explanation: Since Bob is already holding the...
# 197   Explanation: Since Bob is holding the tomato,...
#
#     mistral_Mixtral-8x7B-Instruct-v01 Answer Ordinal  ...
# 0                                                  B  ...  \
# 1                                                  A  ...
# 2                                                  N  ...
# 3                                                  D  ...
# 4                                                  A  ...
# ..                                               ...  ...
# 193                                                A  ...
# 194                                                B  ...
# 195                                                A  ...
# 196                                                C  ...
# 197                                                A  ...
#
#      vicuna_vicuna-13b-v15 Answer Correct
# 0                                       0  \
# 1                                       0
# 2                                       0
# 3                                       0
# 4                                       1
# ..                                    ...
# 193                                     0
# 194                                     1
# 195                                     0
# 196                                     0
# 197                                     0
#
#                       llama_Llama-2-13b-chat-hf Answer
# 0      Based on the information provided, the answe...  \
# 1      Based on the information provided, it is mos...
# 2      Explanation: Based on the current informatio...
# 3      Based on the information provided, we can se...
# 4      Based on the information provided, it would ...
# ..                                                 ...
# 193    Explanation: Based on the current state info...
# 194    Explanation: Since I am holding nothing and ...
# 195    Explanation: In order to begin cooking the s...
# 196    Explanation: Based on the current state info...
# 197    Explanation: Since I am holding nothing and ...
#
#     llama_Llama-2-13b-chat-hf Answer Ordinal
# 0                                          C  \
# 1                                          B
# 2                                          D
# 3                                          B
# 4                                          A
# ..                                       ...
# 193                                        A
# 194                                        A
# 195                                        A
# 196                                        A
# 197                                        A
#
#      llama_Llama-2-13b-chat-hf Answer Correct
# 0                                           0  \
# 1                                           0
# 2                                           0
# 3                                           0
# 4                                           0
# ..                                        ...
# 193                                         0
# 194                                         1
# 195                                         0
# 196                                         1
# 197                                         0
#
#                       llama_Llama-2-70b-chat-hf Answer
# 0      Explanation: Based on the information provid...  \
# 1      E. Reveal Bob's rank 1 cards.\n\nExplanation...
# 2      Explanation: We want to play a card that wil...
# 3      Based on the information provided, the curre...
# 4      Based on the information provided, the best ...
# ..                                                 ...
# 193    Explanation: Since Bob is holding a plate an...
# 194    Explanation: We want to maximize the number ...
# 195    Explanation: The cooker already has 2 onions...
# 196    Explanation: Since Bob is holding a tomato a...
# 197    Explanation: We need to prioritize getting t...
#
#     llama_Llama-2-70b-chat-hf Answer Ordinal
# 0                                          B  \
# 1                                          E
# 2                                          K
# 3                                          A
# 4                                          E
# ..                                       ...
# 193                                        A
# 194                                        C
# 195                                        F
# 196                                        A
# 197                                        A
#
#      llama_Llama-2-70b-chat-hf Answer Correct
# 0                                           1  \
# 1                                           1
# 2                                           0
# 3                                           0
# 4                                           1
# ..                                        ...
# 193                                         0
# 194                                         0
# 195                                         0
# 196                                         1
# 197                                         0
#
#                               openai_gpt-4-0125 Answer
# 0    Explanation: Based on the information provided...  \
# 1    Explanation: Since the game is at the beginnin...
# 2    Explanation: Since it's the start of the game ...
# 3    Explanation: The game's current state shows th...
# 4    Explanation: Given the current stacks, the nex...
# ..                                                 ...
# 193  Explanation: Since the cooker contains 2 onion...
# 194  Explanation: Since the cooker already has the ...
# 195  Explanation: Based on the game's rules and you...
# 196  Explanation: Since the cooker already has 2 on...
# 197  Explanation: Since the cooker already has the ...
#
#     openai_gpt-4-0125 Answer Ordinal  openai_gpt-4-0125 Answer Correct
# 0                                  B                                 1
# 1                                  B                                 0
# 2                                  L                                 0
# 3                                  E                                 1
# 4                                  E                                 1
# ..                               ...                               ...
# 193                                A                                 0
# 194                                D                                 0
# 195                                C                                 1
# 196                                A                                 1
# 197                                C                                 1
#
# [198 rows x 26 columns]

# %%
# JP Synthesis Failures 

jp_sf = error_logs[error_logs[f'{m} Answer Correct']]


# JP Component Failures

# %%
cols = [f'{m} Answer Correct' for m in all_models]

jp_error_logs = error_logs.loc[error_logs['Type'] == 'JP']
jp_error_logs_wrong = jp_error_logs.loc[jp_error_logs[cols].sum(axis=1) < 2]

tom_error_logs = error_logs.loc[error_logs['Type'] == 'TOM']
tom_error_logs_wrong = tom_error_logs.loc[tom_error_logs[cols].sum(axis=1) < 2]

ec_error_logs = error_logs.loc[error_logs['Type'] == 'EC']
ec_error_logs_wrong = ec_error_logs.loc[ec_error_logs[cols].sum(axis=1) < 2]

# %%
jp_error_logs_wrong.to_csv('jp_error_logs.csv')

# %%
errors = {all_models[i]: {'ec': [], 'tom': [], 'jp': []} for i in range(len(all_models))}
errors_df = pd.DataFrame(columns=['Model', 'Question', 'Inference', 'Ground Truth', 'Ground Truth Ordinal', 'Type'])
# for all models in logs, check the EC Answers, TOM Answers and JP Answers with the ground truth answers from the df, if the answer does not match add it to the corresponding dict key in errors
for model in all_models:
    for i in range(len(ec_ans)):
        
        if find_answer_fuzzy(ec_questions[i],logs[model]['EC_ANSWERS'][i]) not in ec_ans_ord[i]:
            new_row = pd.DataFrame({'Model': [model], 'Question': [ec_questions[i]], 'Inference': logs[model]['EC_ANSWERS'][i], 'Ground Truth': [ec_ans[i]], 'Ground Truth Ordinal': ec_ans_ord[i], 'Type': ['EC']})
            errors_df = pd.concat([errors_df, new_row], ignore_index=True)
            errors[model]['ec'].append(logs[model]['EC_ANSWERS'][i])
        
        if find_answer_fuzzy(tom_questions[i],logs[model]['TOM_ANSWERS'][i]) not in tom_ans_ord[i]:
            new_row = pd.DataFrame({'Model': [model], 'Question': [tom_questions[i]], 'Inference': logs[model]['TOM_ANSWERS'][i], 'Ground Truth': [tom_ans[i]],  'Ground Truth Ordinal': tom_ans_ord[i], 'Type': ['TOM']})
            errors_df = pd.concat([errors_df, new_row], ignore_index=True)
            errors[model]['tom'].append(logs[model]['TOM_ANSWERS'][i])
        
        if find_answer_fuzzy(jp_questions[i],logs[model]['JP_ANSWERS'][i]) not in jp_ans_ord[i]:
            new_row = pd.DataFrame({'Model': [model], 'Question': [jp_questions[i]], 'Inference': logs[model]['JP_ANSWERS'][i], 'Ground Truth': [jp_ans[i]], 'Ground Truth Ordinal': jp_ans_ord[i], 'Type': ['JP']})
            errors_df = pd.concat([errors_df, new_row], ignore_index=True)
            errors[model]['jp'].append(logs[model]['JP_ANSWERS'][i])
# Out:
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']
# WARNING:root:Applied processor reduces input query to empty string, all comparisons will have score 0. [Query: '']

# %%
error_logs
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 error_logs
#
# NameError: name 'error_logs' is not defined

# %%
errors_df.to_csv('errors.csv')

# %%
ls = errors['llama_Llama-2-13b-chat-hf']['ec']
# print this list to a file like a bullet point list, remove all \n and \t
ls = [re.sub(r'\n', '', l) for l in ls]
ls = [re.sub(r'\t', '', l) for l in ls]
with open('errors_llama_Llama-2-13b-chat-hf.txt', 'w') as f:
    for l in ls:
        f.write(f'{l}\n')

# %%
# find errors for ec that are there in errors of all models 
ec_errors = set(errors[all_models[0]]['ec'])
# for model in all_models:
#     ec_errors = ec_errors.intersection(set(errors[model]['ec']))

# %%
ec_errors
# Out:
# {' Analysis: Since I am closer to Room 2 where the thief is, opening the door between Room 1 and 2 will increase the chances of trapping the thief.\n\nAction: A. I should open one of the doors.\nAnswer: A. Alice should open one of the doors.',
#  ' Answer: A. No, we can get to the gate perfectly fine.\n\nExplanation: Since the killer is in room 7 and the exit gate is in room 1 (connected to room 7), and we have already fixed the generators, Alice and Bob can safely make their way to the exit gate and escape without the need to lure the killer away.',
#  " Answer: C. Not enough information.\n\nExplanation: Since the killer is in the Backyard area, which is connected to the Gate area, there is no need for the survivors to lure the killer away to access the gate, as long as they can reach it before or at the same time as the killer. However, without knowing their exact positions and movement possibilities in the next turn, it's impossible to confirm that for certain.",
#  ' Based on the given conventions, both Alice and Bob are responsible for passing onions and plates to each other. Therefore, the answer is B. Both of us.',
#  " Based on the information provided, the answer is:\n\nC. Not enough information.\n\nThe decision would depend on the location of the closest available cooker and the distance to the shared counter. Without this information, it's not possible to determine which option is quicker.",
#  ' Based on the provided information, the answer is C. Not enough information. The scenario does not indicate whether both players can reach the same onion dispenser at the same time, as their positions and the location of the onion dispensers are not specified in the given information.',
#  " Based on the provided information, the answer is:\n\nC. Not enough information.\n\nExplanation: In order to determine if Bob can deliver the soup on his own, we need to know the location of the delivery area d0 in relation to Bob. If d0 is within his reach, then he can deliver the soup. However, the information provided does not mention Bob's distance to d0.",
#  " C. Not enough information. Since I'm not holding any ingredient and Bob is holding an onion, we don't have enough ingredients to fill the cooker with one onion and one tomato in this turn. However, we could potentially start preparing the next soup if the cooker is free and we can obtain the tomato.",
#  ' C. Not enough information. Since we cannot see the status of the delivery area or the gates, it is unclear if Bob is able to deliver his soup or not.',
#  " C. Not enough information. Since we have agreed to maximize the number of cooked soups and deliveries, it's important to consider the next steps in the process. If we can coordinate efficiently, it may be beneficial for me to pick up an onion and start cooking a new soup while Bob handles the delivery. However, without knowing the state of the delivery area and any potential obstacles or delays, it's difficult to definitively say whether I should wait for Bob to handle the delivery or not.",
#  " C. Not enough information. The killer moves towards the agent closest to it, so the answer depends on the location of the agent closest to the killer at the moment. We don't have that information.",
#  " C. Not enough information. The killer's current location and movement intentions are known, but we don't have enough information about the killer's movements or the possible actions of Alice and Bob to determine if Bob can safely access generator 1.",
#  " C. Not enough information. The killer's position in relation to Alice's path to the exit gate depends on the specific room connections between Forest, Warehouse, Kitchen, and the Gate area. Without this information, it's impossible to determine if the killer is blocking Alice's path.",
#  ' C. Not enough information. We need to check if one of us has a plate and if there is a cooked soup on the cooker.',
#  ' Explanation: Based on the current rules, a player can give a clue on their turn even if they have already received a clue on their previous turn. Therefore, Bob will still be able to give a clue on his next turn.\n\nAnswer: A.',
#  " Explanation: Based on the current state of the game and the information provided, I cannot reveal any information about Bob's cards this turn as I don't have any reveal tokens left.\nAnswer: C. Not enough information.",
#  " Explanation: Based on the current state of the game, I cannot reveal any information about Bob's cards this turn as I have no remaining reveal tokens.\nAnswer: C. Not enough information.",
#  ' Explanation: Based on the current state of the game, none of the stacks are completed as each stack still requires cards with ranks 3, 4, and 5 to be played.\nAnswer: A.',
#  ' Explanation: Based on the current state of the game, only one stack (Red) has been completed, as the Red stack has all its cards in the correct sequence. The other stacks still have cards that need to be played.\nAnswer: C. 3 stacks.',
#  " Explanation: Based on the current state of the game, we cannot determine with certainty if any of Bob's cards are no longer playable for the rest of the game. However, we do know that Bob has revealed some of his cards, which might limit the possibilities for some cards. For instance, since Bob has revealed Green 1 and Green 3, we know that his Green 2 cannot be a 1 or a 3. But, it could still be any other rank. Similarly, since we don't know the rank of Bob's Card 0 and Card 4, we cannot definitively say if any of those cards are no longer playable. Therefore, the answer is D. Not enough information.",
#  " Explanation: Based on the given information, Bob's Green 3 card is the only card that is immediately playable on his next turn. Therefore, the answer is B.\n\nAnswer: B.",
#  " Explanation: Based on the given information, there are no cards in Bob's hand that are unique rank 2 cards or the last of their kind, as all the cards in his hand have been identified by their ranks. Therefore, no save clues are needed for his cards.\n\nAnswer: B.",
#  " Explanation: Based on the given information, we cannot determine for certain if Bob has any cards that are no longer playable for the rest of the game. However, we can see that Bob's Card 3 (Red 3) has been discarded by Alice, so it is no longer in play. But, this does not necessarily mean that it is no longer playable for the rest of the game, as it could still be revealed or saved as a clue by either player. Therefore, the answer is D. Not enough information.",
#  ' Explanation: Based on the given scenario, the cookers are located in the right partition where Alice is currently located. Therefore, Alice is responsible for putting the ingredients in the cookers.\nAnswer: A. I am.',
#  ' Explanation: Based on the information provided, Bob has a Yellow 2 that is immediately playable on the Yellow Stack. Therefore, the answer is C.\n\nAnswer: C.',
#  " Explanation: Based on the information provided, we cannot determine if Bob has any cards that are the last of their kind in his hand, as we don't have enough information about the cards that Bob still holds. Answer: C.",
#  " Explanation: Based on the information provided, we cannot determine if Bob has any cards that are the last of their kind in his hand. The discard pile does not contain any cards that match the ranks or colors of Bob's remaining cards. Therefore, the answer is C. Not enough information.\n\nAnswer: C.",
#  ' Explanation: Based on the provided information, Bob has a Green 5 and a Green 5 in his hand, so there are no cards in his hand that are the last of their kind and need to be saved.\nAnswer: B.',
#  ' Explanation: Based on the provided information, I can see that one card has been played on each stack except for the Green stack. Therefore, the answer is B.\nAnswer: B.',
#  ' Explanation: Based on the provided information, it is not possible to determine if Bob has any cards that are the last of their kind in his hand. The discard pile only reveals that a Red 2 has been discarded, but it does not give any information about the ranks or colors of the cards that Bob still holds. Therefore, the answer is C. Not enough information.\n\nAnswer: C.',
#  " Explanation: Based on the provided information, none of Bob's cards are the last of their kind in his hand.\nAnswer: B.",
#  " Explanation: Based on the provided information, there is no card in Bob's hand or the discard pile that is unique (only one of its kind) and of rank 5.\nAnswer: C. Not enough information. (However, based on the current state, the answer is B. No.)",
#  ' Explanation: Based on the rules of the game, a player can give a clue even if they have already played a card on their turn. Therefore, Bob will still be able to give a clue on his turn.\nAnswer: A.',
#  ' Explanation: I am closer to onion dispenser o0, which contains the last onion. Therefore, I am in a better position to put the last onion in c0.\n\nAnswer: A. I am.',
#  ' Explanation: In order to cook a soup in c0, Alice needs to place 3 onions in it. Since c0 currently contains 2 out of 3 onions, she needs to get 1 more onion to start cooking.\n\nAnswer: C. 1.',
#  ' Explanation: In order to cook soup in Overcooked, you need both an onion and a tomato. However, since I am currently holding nothing and Bob is holding the tomato, we are missing an onion to begin cooking the soup.\n\nAnswer: A. 1 onion.',
#  ' Explanation: In order to cook the next soup, we need 3 onions. Since one onion is already in my inventory, and Bob is holding a plate, we will need to get 2 more onions.\n\nAnswer: C. 2 onions.',
#  ' Explanation: In order to fill up c0, we need to add 3 more onions since there is already 3 onions in it.\n\nAnswer: A. 4 or more. (This answer is incorrect, but it is the closest to the correct answer as per the given question options. According to the given conventions, we should make optimal use of all available cookers and counters, so we should aim for the exact number of onions needed. The correct answer is B: 3.)',
#  ' Explanation: In the current state, neither of us has a soup cooking or a plate, and the delivery area is inaccessible to both of us. Therefore, we cannot deliver any soups at this moment. However, according to our conventions, we will make optimal use of all available cookers and counters to prepare soups for delivery as soon as possible. Since there are no soups being cooked or delivered at the moment, neither of us is in charge of delivering soups.\n\nAnswer: C. Neither of us.',
#  ' Explanation: In this situation, playing an incorrect card would result in losing a life. Therefore, the answer is D.\n\nAction: None (I am waiting for your next move).',
#  ' Explanation: Since I (Alice) am in Room 6 and the thief is in Room 2, we do not have direct access to the thief as there is no direct path from Room 6 to Room 2. However, since the thief moves towards the player who is closest to him, Bob in this case, and the doors can be controlled, we can coordinate our moves to trap the thief.\n\nAnswer: C. Not enough information (However, the answer would be B if we only considered the current state without considering the ability to coordinate actions).',
#  " Explanation: Since the killer is moving to room 1 after Alice's turn, Bob is not in immediate danger of being caught if Alice fixes the generator in room 1. However, they still need to open the exit gate, which requires both generators to be fixed. Since generator 2 is already fixed, the only thing preventing them from escaping is the need for Alice to fix the last repair on generator 1.\n\nAnswer: C. No, they still need to fix generator 2.",
#  ' Explanation: Since we have decided to make optimal use of all available cookers and counters, and we both have empty plates, it makes sense for us to each pick up an onion and go to our respective cookers to start preparing a soup. Once our soups are cooking, we can pick up plates and deliver them to the delivery area or place them on an empty counter to prepare the next soup. In this scenario, since there is an empty counter (k2) close to both of us, it would be beneficial for us to each place our empty plates on that counter and then pick up an onion to start preparing our soups. Therefore, it makes sense for us to both be holding a plate right now.\n\nAnswer: A. Yes.',
#  ' Explanation: The cookers are located between Alice and Bob, so both of their onion dispensers are equidistant from the cookers.\n\nAnswer: D. They are equidistant.',
#  ' Explanation: We need both onions on the cooker to start cooking soup.\nAnswer: C. We are missing one onion.'}

# %%
import pandas as pd

# save a new errors df that contains the model name, the question, the inference string and the ground truth answer, also add another field for the type of question
errors_df = pd.DataFrame(columns=['Model', 'Question', 'Inference', 'Ground Truth', 'Type'])
for model in all_models:
    for i in range(len(errors[model]['ec'])):
        new_row = pd.DataFrame({'Model': [model], 'Question': [ec_questions[i]], 'Inference': [errors[model]['ec'][i]], 'Ground Truth': [ec_ans[i]], 'Type': ['EC']})
        errors_df = pd.concat([errors_df, new_row], ignore_index=True)
    for i in range(len(errors[model]['tom'])):
        new_row = pd.DataFrame({'Model': [model], 'Question': [tom_questions[i]], 'Inference': [errors[model]['tom'][i]], 'Ground Truth': [tom_ans[i]], 'Type': ['TOM']})
        errors_df = pd.concat([errors_df, new_row], ignore_index=True)
    for i in range(len(errors[model]['jp'])):
        new_row = pd.DataFrame({'Model': [model], 'Question': [jp_questions[i]], 'Inference': [errors[model]['jp'][i]], 'Ground Truth': [jp_ans[i]], 'Type': ['JP']})
        errors_df = pd.concat([errors_df, new_row], ignore_index=True)

errors_df.to_csv('errors.csv', index=False)
